# %% [markdown]
# <a href="https://colab.research.google.com/github/mansooraha/ML_projects/blob/main/Pandas_Group_By_and_Aggregation_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/fake_superstore_data.csv')

# %%
df
# Out:
#       Region         Category Sub-Category      Segment    Sales  Quantity  \
# 0    Central        Furniture       Tables    Corporate  4502.89         2
# 1      South        Furniture      Binders    Corporate  1950.26         7
# 2       East  Office Supplies       Chairs  Home Office  2740.59         3
# 3    Central       Technology       Chairs     Consumer  4537.04         2
# 4    Central       Technology       Phones     Consumer  3139.98         7
# ..       ...              ...          ...          ...      ...       ...
# 295    South        Furniture       Tables  Home Office  2720.48         7
# 296     West        Furniture       Chairs  Home Office  3964.08         5
# 297  Central  Office Supplies  Accessories     Consumer  1627.82         7
# 298     East  Office Supplies       Tables     Consumer  3148.16         3
# 299    South        Furniture      Storage     Consumer  4435.59         2
#
#      Discount  Profit  Order Date
# ...

# %% [markdown]
# 1. Find total sales and average quantity for each region

# %%
region_stats = df.groupby('Region')[['Sales', 'Quantity']].agg({'Sales': 'sum', 'Quantity': 'mean'})
region_stats
# Out:
#              Sales  Quantity
# Region
# Central  189540.84  4.714286
# East     177913.73  5.189189
# South    194745.03  5.012346
# West     184155.79  5.161765

# %% [markdown]
# 2. For each category, compute standard deviation and CV of sales

# %%
category_stats = df.groupby('Category')['Sales'].agg(['mean', 'std'])
category_stats['CV'] = category_stats['std'] / category_stats['mean']
category_stats
# Out:
#                         mean          std        CV
# Category
# Furniture        2514.805000  1431.038605  0.569046
# Office Supplies  2320.574681  1454.180007  0.626647
# Technology       2612.608269  1430.570305  0.547564

# %% [markdown]
# 3. Create column high_discount = True if discount > average of that segment

# %%
segment_avg_discount = df.groupby('Segment')['Discount'].transform('mean')
df['high_discount'] = df['Discount'] > segment_avg_discount
segment_avg_discount.head(3)
# Out:
# 0    0.254151
# 1    0.254151
# 2    0.245500
# Name: Discount, dtype: float64

# %% [markdown]
# 4.Filter sub-categories where total sales > 10,000

# %%
subcat_sales = df.groupby('Sub-Category')['Sales'].sum()
high_sales_subcats = subcat_sales[subcat_sales > 10000]
high_sales_subcats
# Out:
# Sub-Category
# Accessories     90823.50
# Binders         85233.99
# Chairs         147605.25
# Phones         112811.59
# Storage        179658.19
# Tables         130222.87
# Name: Sales, dtype: float64
