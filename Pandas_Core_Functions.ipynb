# %% [markdown]
# <a href="https://colab.research.google.com/github/mansooraha/ML_projects/blob/main/Pandas_Core_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df[['total_bill', 'tip', 'sex']].head()
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
df['bill_per_person'] = df['total_bill'] / df['size']
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  bill_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2         8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3         3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3         7.003333

# %%
df['is_weekend'] = df['day'].isin(['Sat', 'Sun'])
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  bill_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2         8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3         3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3         7.003333
#
#    is_weekend
# 0        True
# 1        True
# 2        True

# %%
grouped = df.groupby('day')[['total_bill', 'tip']].mean()
grouped
# Out:
# /tmp/ipython-input-25-243869439.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby('day')[['total_bill', 'tip']].mean()
#       total_bill       tip
# day
# Thur   17.682742  2.771452
# Fri    17.151579  2.734737
# Sat    20.441379  2.993103
# Sun    21.410000  3.255132

# %%
df['smoker'].value_counts().plot.pie(autopct='%1.1f%%', title='Smokers')
plt.ylabel('')
plt.show()

# %%
df['tip'].plot.hist(bins=10, title='Tips')
plt.xlabel('Tip')
plt.show()
